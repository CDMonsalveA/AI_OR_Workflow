# %%
import pandas as pd

def get_produccion(path: str)->pd.DataFrame:
    """
    Function that reads the excel file in the path and returns a dataframe
    with the production data, for the data of producción agricola provided
    by the DANE

    todo: #9 check the provider of the data and the license

    Parameters
    ----------
    path: str
        path to the excel file

    Returns
    -------
    pd.DataFrame
        dataframe with the production data
            columns: ['código dane departamento', 'departamento', 'código dane municipio',
       'municipio', 'desagregación cultivo', 'cultivo', 'ciclo del cultivo',
       'grupo cultivo', 'subgrupo', 'año', 'periodo', 'área sembrada (ha)',
       'área cosechada (ha)', 'producción (t)', 'rendimiento (t/ha)',
       'código del cultivo', 'nombre científico del cultivo',
       'estado físico del cultivo']
            #TODO: #10 add columns
    """
    df = pd.read_excel(path)
    df.columns = df.columns.str.lower()
    # if the value of the length of the str in 'código dane municipio' is not 5
    # add a 0 at the beginning
    # and then if the value of the length of the str in 'código dane municipio' is not 5
    # add a 0 at the end
    # and then if the value of the length of the str in 'código dane municipio' is not 5
    # add a 0 at the end
    df['código dane municipio'] = df['código dane municipio'].astype(str)
    df['código dane municipio'] = df['código dane municipio'].apply(lambda x: "0"+ x if len(x) != 5 else x)
    df['código dane municipio'] = df['código dane municipio'].apply(lambda x: x + "0" if len(x) != 5 else x)
    df['código dane municipio'] = df['código dane municipio'].apply(lambda x: x + "0" if len(x) != 5 else x)
    return df

def pivot_per_municipio(df: pd.DataFrame, columns: list, values: str)->pd.DataFrame:
    """
    Function that pivots the dataframe to have the production data per
    municipio

    Parameters
    ----------
    df: pd.DataFrame
        dataframe with the production data

    Returns
    -------
    pd.DataFrame
        dataframe with the production data per municipio
    """
    index = ['código dane departamento', 'departamento', 'código dane municipio',
       'municipio']
    df = df.pivot_table(index=index, columns=columns, values=values)
    return df

df = get_produccion("produccion\produccion_agricola_2019_2022.xlsx")
df_pivot = pivot_per_municipio(df,columns=['grupo cultivo'], values='producción (t)')

display(df_pivot)
# Out:
# grupo cultivo                                                                 Cereales  \
# código dane departamento departamento código dane municipio municipio
# 5                        Antioquia    05001                 Medellín               NaN
#                                       05002                 Abejorral       115.500000
#                                       05004                 Abriaquí          8.666667
#                                       05021                 Alejandría       22.507500
#                                       05030                 Amagá             7.510000
# ...                                                                                ...
# 97                       Vaupés       97666                 Taraira          18.500000
# 99                       Vichada      99001                 Puerto Carreño  115.576923
#                                       99524                 La Primavera    346.518333
#                                       99624                 Santa Rosalía    52.035625
#                                       99773                 Cumaribo         87.338889
#
# grupo cultivo                                                               Cultivos Tropicales Tradicionales  \
# código dane departamento departamento código dane municipio municipio
# 5                        Antioquia    05001                 Medellín                              2522.785000
#                                       05002                 Abejorral                             4848.210833
#                                       05004                 Abriaquí                              2625.507500
#                                       05021                 Alejandría                            4098.661667
#                                       05030                 Amagá                                 1055.816250
# ...                                                                                                       ...
# 97                       Vaupés       97666                 Taraira                                  9.123333
# 99                       Vichada      99001                 Puerto Carreño                        1164.000000
#                                       99524                 La Primavera                           738.525000
#                                       99624                 Santa Rosalía                          448.500000
#                                       99773                 Cumaribo                              4232.337500
#
# grupo cultivo                                                               Cultivos para Condimentos y Bebidas Medicinales y Aromáticas  \
# código dane departamento departamento código dane municipio municipio
# 5                        Antioquia    05001                 Medellín                                                     17.2
#                                       05002                 Abejorral                                                     NaN
#                                       05004                 Abriaquí                                                      NaN
#                                       05021                 Alejandría                                                    NaN
#                                       05030                 Amagá                                                         6.0
# ...                                                                                                                       ...
# 97                       Vaupés       97666                 Taraira                                                       NaN
# 99                       Vichada      99001                 Puerto Carreño                                                NaN
#                                       99524                 La Primavera                                                  NaN
#                                       99624                 Santa Rosalía                                                 NaN
#                                       99773                 Cumaribo                                                      NaN
#
# grupo cultivo                                                                  Frutales  \
# código dane departamento departamento código dane municipio municipio
# 5                        Antioquia    05001                 Medellín         230.930638
#                                       05002                 Abejorral       3113.091667
#                                       05004                 Abriaquí         242.477273
#                                       05021                 Alejandría       270.225000
#                                       05030                 Amagá            120.920000
# ...                                                                                 ...
# 97                       Vaupés       97666                 Taraira          119.713500
# 99                       Vichada      99001                 Puerto Carreño  8446.176667
#                                       99524                 La Primavera    3002.008333
#                                       99624                 Santa Rosalía    393.857143
#                                       99773                 Cumaribo        2318.666667
#
# grupo cultivo                                                               Hortalizas  \
# código dane departamento departamento código dane municipio municipio
# 5                        Antioquia    05001                 Medellín        409.852087
#                                       05002                 Abejorral              NaN
#                                       05004                 Abriaquí        113.341111
#                                       05021                 Alejandría       16.937500
#                                       05030                 Amagá           100.222222
# ...                                                                                ...
# 97                       Vaupés       97666                 Taraira          59.062500
# 99                       Vichada      99001                 Puerto Carreño   35.363636
#                                       99524                 La Primavera     75.675000
#                                       99624                 Santa Rosalía    35.416667
#                                       99773                 Cumaribo         24.318182
#
# grupo cultivo                                                               Leguminosas  \
# código dane departamento departamento código dane municipio municipio
# 5                        Antioquia    05001                 Medellín          41.758235
#                                       05002                 Abejorral        147.252500
#                                       05004                 Abriaquí          32.614375
#                                       05021                 Alejandría        30.562500
#                                       05030                 Amagá              5.820000
# ...                                                                                 ...
# 97                       Vaupés       97666                 Taraira                 NaN
# 99                       Vichada      99001                 Puerto Carreño     0.000000
#                                       99524                 La Primavera            NaN
#                                       99624                 Santa Rosalía     15.730000
#                                       99773                 Cumaribo                NaN
#
# grupo cultivo                                                               Oleaginosas  \
# código dane departamento departamento código dane municipio municipio
# 5                        Antioquia    05001                 Medellín                NaN
#                                       05002                 Abejorral               NaN
#                                       05004                 Abriaquí                NaN
#                                       05021                 Alejandría              NaN
#                                       05030                 Amagá                   NaN
# ...                                                                                 ...
# 97                       Vaupés       97666                 Taraira                 NaN
# 99                       Vichada      99001                 Puerto Carreño         4.15
#                                       99524                 La Primavera       15053.41
#                                       99624                 Santa Rosalía       8857.60
#                                       99773                 Cumaribo               2.25
#
# grupo cultivo                                                               Raíces y Tubérculos  \
# código dane departamento departamento código dane municipio municipio
# 5                        Antioquia    05001                 Medellín                 380.552667
#                                       05002                 Abejorral                843.750000
#                                       05004                 Abriaquí                   5.152941
#                                       05021                 Alejandría                79.875000
#                                       05030                 Amagá                    165.300000
# ...                                                                                         ...
# 97                       Vaupés       97666                 Taraira                  376.673846
# 99                       Vichada      99001                 Puerto Carreño           126.875000
#                                       99524                 La Primavera            1265.375000
#                                       99624                 Santa Rosalía            278.375000
#                                       99773                 Cumaribo                4030.000000
#
# grupo cultivo                                                               Raíces y tubérculos
# código dane departamento departamento código dane municipio municipio
# 5                        Antioquia    05001                 Medellín                        NaN
#                                       05002                 Abejorral                       NaN
#                                       05004                 Abriaquí                        NaN
#                                       05021                 Alejandría                      NaN
#                                       05030                 Amagá                           NaN
# ...                                                                                         ...
# 97                       Vaupés       97666                 Taraira                         NaN
# 99                       Vichada      99001                 Puerto Carreño                  NaN
#                                       99524                 La Primavera                    NaN
#                                       99624                 Santa Rosalía                   NaN
#                                       99773                 Cumaribo                        NaN
#
# [1100 rows x 9 columns]
# array([5], dtype=int64)
